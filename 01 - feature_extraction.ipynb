# %%
# Reload and changes to module without having to restart kernel.
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
from plotnine import *

import scipy.stats

import requests

# %% [markdown]
# ### Load provided data

# %%
JGI_DATA = pd.read_excel('../loneliness-data/jgi_data.xlsx', sheet_name=1)

# %%
JGI2016, JGI2017, JGI2018 = JGI_DATA.groupby('Year')

# %%
# For now, just set the data from 2018 as the target variable
all_data = JGI2018[1].set_index('pcstrip')

# %%
JGI2018[1].columns = JGI2018[1].columns.str.replace(" ", "")

# %%
# test = JGI2018[1].merge(features, left_on='pcstrip', right_index=True)

# %%
# features_lad = test.groupby('laua').mean()[['target',
#        'A1', 'B1', 'C1', 'C2', 'D1', 'D2', 'E1', 'E2', 'F1', 'F2', 'region_1',
#        'region_2', 'region_3', 'region_4', 'region_5', 'region_6', 'region_7',
#        'region_8', 'region_9', 'index_multiple_deprivation', '0-9', '10-24',
#        '25-49', '50-79', '80+', 'nearby_schools', 'Academy', 'College',
#        'Independent School', 'Maintained School', 'Special School', 'in_0-9',
#        'in_10-24', 'in_25-49', 'in_50-79', 'in_80+', 'out_0-9', 'out_10-24',
#        'out_25-49', 'out_50-79', 'out_80+', 'moves_in_zscore',
#        'moves_out_zscore', 'schools_many', 'prop_score', 'norm_0-9',
#        'norm_10-24', 'norm_25-49', 'norm_50-79', 'norm_80+', 'ru_rank',
#        'tot_patients', 'nearby_schools_zscore', 'norm_in_0-9', 'norm_in_10-24',
#        'norm_in_25-49', 'norm_in_50-79', 'norm_in_80+', 'norm_out_0-9',
#        'norm_out_10-24', 'norm_out_25-49', 'norm_out_50-79', 'norm_out_80+']]

# %% [markdown]
# # Rural/Urban index, Region of countries feature

# %%
features = pd.DataFrame(index=all_data.index)

features['target'] = all_data['loneills']
features['target2'] = JGI2018[1]['socialanxiety_zscore'].values

# %%
to_num = {"A1":10, "B1":9, "C1":8, "C2":7,"D1":6, "D2":5, "E1":4,"E2":3,"F1":2,"F2":1}
features['ru_rank'] = all_data.ru11ind.apply(lambda x: to_num[x])

# %%
rural_urban = pd.get_dummies(all_data.ru11ind)
features = pd.concat([features, rural_urban], axis=1)

country_region = pd.get_dummies(all_data.rgn)
country_region.columns = 'region_'+country_region.columns.str[-1:]
features = pd.concat([features, country_region], axis=1)

features['index_multiple_deprivation'] = all_data.imd

# %%
country_region
# Out:
#          region_1  region_2  region_3  region_4  region_5  region_6  region_7  \
# pcstrip
# AL100BS         0         0         0         0         0         1         0
# AL100NL         0         0         0         0         0         1         0
# AL108HP         0         0         0         0         0         1         0
# AL13FY          0         0         0         0         0         1         0
# AL13HD          0         0         0         0         0         1         0
# AL13JB          0         0         0         0         0         1         0
# AL14JE          0         0         0         0         0         1         0
# AL21ES          0         0         0         0         0         1         0
# AL21EU          0         0         0         0         0         1         0
# AL23JX          0         0         0         0         0         1         0
# AL35ER          0         0         0         0         0         1         0
# AL35HB          0         0         0         0         0         1         0
# AL35NF          0         0         0         0         0         1         0
# AL35NP          0         0         0         0         0         1         0
# AL37BL          0         0         0         0         0         1         0
# AL38LJ          0         0         0         0         0         1         0
# AL52BT          0         0         0         0         0         1         0
# AL54HX          0         0         0         0         0         1         0
# AL54QA          0         0         0         0         0         1         0
# AL69EF          0         0         0         0         0         1         0
# AL73UJ          0         0         0         0         0         1         0
# AL74HL          0         0         0         0         0         1         0
# AL74PL          0         0         0         0         0         1         0
# AL87QG          0         0         0         0         0         1         0
# AL97SN          0         0         0         0         0         1         0
# B100BS          0         0         0         0         1         0         0
# B100JL          0         0         0         0         1         0         0
# B100TU          0         0         0         0         1         0         0
# B100UG          0         0         0         0         1         0         0
# B109AB          0         0         0         0         1         0         0
# ...           ...       ...       ...       ...       ...       ...       ...
# YO212PA         0         0         1         0         0         0         0
# YO225DP         0         0         1         0         0         0         0
# YO233UA         0         0         1         0         0         0         0
# YO243BZ         0         0         1         0         0         0         0
# YO243WX         0         0         1         0         0         0         0
# YO244DB         0         0         1         0         0         0         0
# YO244HD         0         0         1         0         0         0         0
# YO256EB         0         0         1         0         0         0         0
# YO256UH         0         0         1         0         0         0         0
# YO268BN         0         0         1         0         0         0         0
# YO317YD         0         0         1         0         0         0         0
# YO322LL         0         0         1         0         0         0         0
# YO325UA         0         0         1         0         0         0         0
# YO414DY         0         0         1         0         0         0         0
# YO422BS         0         0         1         0         0         0         0
# YO433FF         0         0         1         0         0         0         0
# YO519BD         0         0         1         0         0         0         0
# YO606PS         0         0         1         0         0         0         0
# YO611LL         0         0         1         0         0         0         0
# YO611QW         0         0         1         0         0         0         0
# YO613JR         0         0         1         0         0         0         0
# YO624EF         0         0         1         0         0         0         0
# YO625HD         0         0         1         0         0         0         0
# YO626AR         0         0         1         0         0         0         0
# YO71LG          0         0         1         0         0         0         0
# YO71LU          0         0         1         0         0         0         0
# YO73RP          0         0         1         0         0         0         0
# YO84BL          0         0         1         0         0         0         0
# YO84QH          0         0         1         0         0         0         0
# YO89AJ          0         0         1         0         0         0         0
#
#          region_8  region_9
# pcstrip
# AL100BS         0         0
# AL100NL         0         0
# AL108HP         0         0
# AL13FY          0         0
# AL13HD          0         0
# AL13JB          0         0
# AL14JE          0         0
# AL21ES          0         0
# AL21EU          0         0
# AL23JX          0         0
# AL35ER          0         0
# AL35HB          0         0
# AL35NF          0         0
# AL35NP          0         0
# AL37BL          0         0
# AL38LJ          0         0
# AL52BT          0         0
# AL54HX          0         0
# AL54QA          0         0
# AL69EF          0         0
# AL73UJ          0         0
# AL74HL          0         0
# AL74PL          0         0
# AL87QG          0         0
# AL97SN          0         0
# B100BS          0         0
# B100JL          0         0
# B100TU          0         0
# B100UG          0         0
# B109AB          0         0
# ...           ...       ...
# YO212PA         0         0
# YO225DP         0         0
# YO233UA         0         0
# YO243BZ         0         0
# YO243WX         0         0
# YO244DB         0         0
# YO244HD         0         0
# YO256EB         0         0
# YO256UH         0         0
# YO268BN         0         0
# YO317YD         0         0
# YO322LL         0         0
# YO325UA         0         0
# YO414DY         0         0
# YO422BS         0         0
# YO433FF         0         0
# YO519BD         0         0
# YO606PS         0         0
# YO611LL         0         0
# YO611QW         0         0
# YO613JR         0         0
# YO624EF         0         0
# YO625HD         0         0
# YO626AR         0         0
# YO71LG          0         0
# YO71LU          0         0
# YO73RP          0         0
# YO84BL          0         0
# YO84QH          0         0
# YO89AJ          0         0
#
# [6610 rows x 9 columns]

# %% [markdown]
# # GP patients feature

# %%
p_data = pd.read_csv('../loneliness-data/gp-patients/gp-reg-pat-prac-quin-age-feb-18.csv', low_memory=False)

# %%
# Our data is for GP practices, remove ALL ages as we want to group by age ranges
p_data = p_data[(p_data['AGE_GROUP_5'] != 'ALL')]

# Make postcodes consistant with JGI data (no space between PC)
p_data.POSTCODE = p_data.POSTCODE.str.replace(" ", "")

# %%
# Find earliest age in each bracket for groupby operation (e.g. 10-14 -> 10, 25-29 -> 25)
p_data['year0'] = p_data.AGE_GROUP_5.str.split("_|\+").apply(lambda z: int(z[0]))

# %%
# Group each column to year bands 0-19, 20-39, ... 80+
ind = np.digitize(p_data['year0'].values,[0, 10, 25, 50, 80])

# For each year band group, group further into postcodes group and then concatenate
# results to get number of patients for each yr band in each postcode
patients = pd.concat([v.groupby('POSTCODE')['NUMBER_OF_PATIENTS'].sum() for (k, v) in p_data.groupby(ind)], axis=1)

patients.columns = ['0_9','10_24','25_49','50_79','80p']
patients.columns = 'gp'+patients.columns

patients.head()

features[patients.columns] = patients

# %%
features['tot_patients'] = patients.sum(axis=1)

# %%
patients_norm = patients.apply(lambda z: z / patients.sum(axis=1))

patients_norm.head()

features["gp_norm_"+patients_norm.columns] = patients_norm

# %% [markdown]
# # Number of schools in 10km radius feature

# %%
edu_SPINE = pd.read_csv("../loneliness-data/ofsted-data/england_spine.csv")

# %%
edu_SPINE = edu_SPINE[~pd.isnull(edu_SPINE['POSTCODE'])]

# %%
edu_SPINE['MINORGROUP'].value_counts()

edu_SPINE['MINORGROUP'] = edu_SPINE['MINORGROUP'].str.replace(" ", "")

# %%
schools = edu_SPINE.POSTCODE.dropna().str.split(" ").apply(lambda z: z[0]).value_counts().sort_index()

# %%
schools = edu_SPINE.POSTCODE.dropna().str.split(" ").apply(lambda z: z[0]).value_counts().sort_index()
result_cache = {}
def nearby_schools(pc):
    pc_outcode = pc[0:-3]
    if pc_outcode in result_cache.keys():
        return result_cache[pc_outcode]
    else:
        try:
            r = requests.get("https://api.postcodes.io/outcodes/"+pc_outcode+"/nearest", {'radius': 10000, 'limit': 100})     
            idx = [x['outcode'] for x in r.json()['result']]
            result_cache[pc_outcode] = schools[schools.index.isin(idx)].sum()
        except KeyError:
            return None
    return result_cache[pc_outcode]

# %%
features['nearby_schools'] = pd.Series(all_data.index, index=all_data.index).apply(lambda x: nearby_schools(x))

# %%
features['nearby_schools_zscore'] = (features['nearby_schools'] - features['nearby_schools'].mean()) / features['nearby_schools'].std()

# %% [markdown]
# # Proportion of schools in 10km radius feature

# %%
schools_detailed = edu_SPINE.groupby(edu_SPINE.POSTCODE.dropna().str.split(" ").apply(lambda z: z[0]))

# %%
schools_detailed = schools_detailed.apply(lambda z: z.MINORGROUP.value_counts(" ")).reset_index().pivot(columns = 'level_1', index='POSTCODE', values='MINORGROUP').fillna(0)

# %%
features = features.merge(schools_detailed, left_on=features.index.str[:-3], right_index=True)

# %%
del features['key_0']

# %% [markdown]
# # Migration features

# %%
d = pd.read_csv("../loneliness-data/2017_la.csv", index_col='Code')

d.head()
# Out:
#            Estimated Population mid-2017
# Code
# K02000001                       66040229
# K03000001                       64169395
# K04000001                       58744595
# E92000001                       55619430
# E12000001                        2644727

# %%
od1 = pd.read_csv("../loneliness-data/Detailed_Estimates_2017_Dataset_1.csv")
od2 = pd.read_csv("../loneliness-data/Detailed_Estimates_2017_Dataset_2.csv")

# %%
od = pd.concat([od1, od2])

# %%
moves_to = od.groupby('InLA').apply(lambda v: v.groupby(np.digitize(v['Age'].values,[0, 10, 25, 50, 80])).sum().T)

moves_to = moves_to.reset_index()
moves_to = moves_to[moves_to.loc[:,'level_1'] == 'Age'].set_index("InLA")
moves_to = moves_to.drop("level_1", axis=1)

moves_to.columns = ['in_0_9','in_10_24','in_25_49','in_50_79','in_80p']

# moves_to = moves_to.apply(lambda z: z / z.sum(), axis=1)

# %%
in_norm_by_pop = moves_to / d.loc[moves_to.index].values

in_norm_by_pop.columns = "norm_"+in_norm_by_pop.columns

# %%
moves_to.head()
# Out:
#            in_0_9  in_10_24  in_25_49  in_50_79  in_80p
# InLA
# E06000001   849.0    7149.0   18681.0   15795.0  2566.0
# E06000002  1333.0   18183.0   31654.0   22406.0  6680.0
# E06000003  1115.0    9340.0   26881.0   33731.0  7114.0
# E06000004  1631.0   17598.0   39442.0   29245.0  6980.0
# E06000005  1160.0    9157.0   27781.0   29388.0  7086.0

# %%
moves_from = od.groupby('OutLA').apply(lambda v: v.groupby(np.digitize(v['Age'].values,[0, 10, 25, 50, 80])).sum().T)

moves_from = moves_from.reset_index()
moves_from = moves_from[moves_from.loc[:,'level_1'] == 'Age'].set_index("OutLA")
moves_from = moves_from.drop("level_1", axis=1)

moves_from.columns = ['out_0_9','out_10_24','out_25_49','out_50_79','out_80p']

# moves_from = moves_from.apply(lambda z: z / z.sum(), axis=1)

# %%
out_norm_by_pop = moves_from / d.loc[moves_from.index].values

out_norm_by_pop.columns = "norm_"+out_norm_by_pop.columns

# %%
out_norm_mig = JGI2018[1][['pcstrip', 'laua']].set_index(JGI2018[1]['pcstrip'], drop=True).merge(out_norm_by_pop, left_on='laua', right_index=True)
out_norm_mig = out_norm_mig[['norm_out_0_9', 'norm_out_10_24', 'norm_out_25_49',
       'norm_out_50_79', 'norm_out_80p']]


in_norm_mig = JGI2018[1][['pcstrip', 'laua']].set_index(JGI2018[1]['pcstrip'], drop=True).merge(in_norm_by_pop, left_on='laua', right_index=True)

in_norm_mig = in_norm_mig[['norm_in_0_9', 'norm_in_10_24', 'norm_in_25_49',
       'norm_in_50_79', 'norm_in_80p']]

# %%
features[in_norm_mig.columns] = in_norm_mig
features[out_norm_mig.columns] = out_norm_mig

# %%
moves_in = JGI2018[1][['pcstrip', 'laua']].set_index(JGI2018[1]['pcstrip'], drop=True).merge(moves_to, left_on='laua', right_index=True)
moves_out = JGI2018[1][['pcstrip', 'laua']].set_index(JGI2018[1]['pcstrip'], drop=True).merge(moves_from, left_on='laua', right_index=True)

moves_in = moves_in[['in_0_9', 'in_10_24', 'in_25_49', 'in_50_79','in_80p']]
moves_out = moves_out[['out_0_9', 'out_10_24', 'out_25_49', 'out_50_79','out_80p']]

# %%
features[moves_in.columns] = moves_in
features[moves_out.columns] = moves_out

# %%
moves_zscore = moves_in.sum(axis=1)
moves_zscore = (moves_zscore - moves_zscore.mean()) / moves_zscore.std()
features['moves_in_zscore'] = moves_zscore


moves_zscore = moves_out.sum(axis=1)
moves_zscore = (moves_zscore - moves_zscore.mean()) / moves_zscore.std()
features['moves_out_zscore'] = moves_zscore

# %%
features
# Out:
#            target   target2  ru_rank  A1  B1  C1  C2  D1  D2  E1  ...  \
# pcstrip                                                           ...
# AL100BS  0.616736  0.937151        8   0   0   1   0   0   0   0  ...
# AL100NL  1.139326  0.796187        8   0   0   1   0   0   0   0  ...
# AL108HP -0.487490  0.587106        8   0   0   1   0   0   0   0  ...
# AL13FY  -1.439142 -1.168025        8   0   0   1   0   0   0   0  ...
# AL13HD   0.655981 -0.084793        8   0   0   1   0   0   0   0  ...
# AL13JB   1.968743  0.975865        8   0   0   1   0   0   0   0  ...
# AL14JE  -2.169246 -1.075872        8   0   0   1   0   0   0   0  ...
# AL21ES  -1.653688 -0.419309        8   0   0   1   0   0   0   0  ...
# AL21EU  -1.369429 -0.406214        8   0   0   1   0   0   0   0  ...
# AL23JX  -0.597209  0.097320        8   0   0   1   0   0   0   0  ...
# AL35ER  -2.040363 -0.586830        8   0   0   1   0   0   0   0  ...
# AL35HB   2.073431  1.304203        8   0   0   1   0   0   0   0  ...
# AL35NF  -0.567533  0.127802        8   0   0   1   0   0   0   0  ...
# AL35NP   2.216519  1.318516        8   0   0   1   0   0   0   0  ...
# AL37BL   0.310553 -0.067687        6   0   0   0   0   1   0   0  ...
# AL38LJ   2.346906  0.504609        6   0   0   0   0   1   0   0  ...
# AL52BT   1.534695  0.529910        8   0   0   1   0   0   0   0  ...
# AL54HX   0.891796  0.957821        8   0   0   1   0   0   0   0  ...
# AL54QA   0.710086  0.495449        8   0   0   1   0   0   0   0  ...
# AL69EF   0.283614 -0.244273        8   0   0   1   0   0   0   0  ...
# AL73UJ   0.606545  1.077339        8   0   0   1   0   0   0   0  ...
# AL74HL  -0.709449  0.819956        8   0   0   1   0   0   0   0  ...
# AL74PL   0.776515  0.590878        8   0   0   1   0   0   0   0  ...
# AL87QG   0.469011  0.680017        8   0   0   1   0   0   0   0  ...
# AL97SN   3.275686  1.950690        4   0   0   0   0   0   0   1  ...
# B100BS  -3.835455 -0.562858       10   1   0   0   0   0   0   0  ...
# B100JL  -5.551664 -0.315037       10   1   0   0   0   0   0   0  ...
# B100TU  -4.230804 -0.979229       10   1   0   0   0   0   0   0  ...
# B100UG  -5.374780 -0.487649       10   1   0   0   0   0   0   0  ...
# B109AB  -3.825282 -0.699021       10   1   0   0   0   0   0   0  ...
# ...           ...       ...      ...  ..  ..  ..  ..  ..  ..  ..  ...
# YO212PA  1.757484  1.443398        4   0   0   0   0   0   0   1  ...
# YO225DP  1.342307  0.388939        5   0   0   0   0   0   1   0  ...
# YO233UA  0.446245  0.348011        6   0   0   0   0   1   0   0  ...
# YO243BZ  1.934667  1.287734        8   0   0   1   0   0   0   0  ...
# YO243WX  2.699800  1.779063        8   0   0   1   0   0   0   0  ...
# YO244DB  0.869571  1.413040        8   0   0   1   0   0   0   0  ...
# YO244HD  2.079193  1.747309        8   0   0   1   0   0   0   0  ...
# YO256EB -0.057973 -0.205331        8   0   0   1   0   0   0   0  ...
# YO256UH -0.917555 -0.122352        8   0   0   1   0   0   0   0  ...
# YO268BN  0.129613  0.524719        4   0   0   0   0   0   0   1  ...
# YO317YD  0.742010  0.745309        8   0   0   1   0   0   0   0  ...
# YO322LL  1.202745  0.841160        8   0   0   1   0   0   0   0  ...
# YO325UA  0.841606  0.962326        6   0   0   0   0   1   0   0  ...
# YO414DY  4.104758  0.855168        4   0   0   0   0   0   0   1  ...
# YO422BS -1.052453  0.408161        6   0   0   0   0   1   0   0  ...
# YO433FF -1.057848  0.380216        6   0   0   0   0   1   0   0  ...
# YO519BD -0.360537  0.469688        6   0   0   0   0   1   0   0  ...
# YO606PS  0.255423  0.192382        4   0   0   0   0   0   0   1  ...
# YO611LL -0.679088 -0.611622        4   0   0   0   0   0   0   1  ...
# YO611QW -0.043671  0.024744        4   0   0   0   0   0   0   1  ...
# YO613JR -0.383285 -0.152659        6   0   0   0   0   1   0   0  ...
# YO624EF -0.550489 -0.022114        4   0   0   0   0   0   0   1  ...
# YO625HD -0.470018 -0.156880        5   0   0   0   0   0   1   0  ...
# YO626AR  0.364664  0.298059        5   0   0   0   0   0   1   0  ...
# YO71LG   0.063448  0.352952        5   0   0   0   0   0   1   0  ...
# YO71LU   1.129892  0.409064        5   0   0   0   0   0   1   0  ...
# YO73RP  -0.873310 -0.469215        4   0   0   0   0   0   0   1  ...
# YO84BL  -1.054304  0.439562        8   0   0   1   0   0   0   0  ...
# YO84QH   0.398306  1.473020        8   0   0   1   0   0   0   0  ...
# YO89AJ  -0.464533  0.744935        8   0   0   1   0   0   0   0  ...
#
#          in_25_49  in_50_79   in_80p  out_0_9  out_10_24  out_25_49  \
# pcstrip
# AL100BS   52502.0   32048.0  10517.0   1690.0    36624.0    62514.0
# AL100NL   52502.0   32048.0  10517.0   1690.0    36624.0    62514.0
# AL108HP   52502.0   32048.0  10517.0   1690.0    36624.0    62514.0
# AL13FY    68783.0   33399.0  14636.0   1919.0    19761.0    71165.0
# AL13HD    68783.0   33399.0  14636.0   1919.0    19761.0    71165.0
# AL13JB    68783.0   33399.0  14636.0   1919.0    19761.0    71165.0
# AL14JE    68783.0   33399.0  14636.0   1919.0    19761.0    71165.0
# AL21ES    68783.0   33399.0  14636.0   1919.0    19761.0    71165.0
# AL21EU    68783.0   33399.0  14636.0   1919.0    19761.0    71165.0
# AL23JX    68783.0   33399.0  14636.0   1919.0    19761.0    71165.0
# AL35ER    68783.0   33399.0  14636.0   1919.0    19761.0    71165.0
# AL35HB    68783.0   33399.0  14636.0   1919.0    19761.0    71165.0
# AL35NF    68783.0   33399.0  14636.0   1919.0    19761.0    71165.0
# AL35NP    68783.0   33399.0  14636.0   1919.0    19761.0    71165.0
# AL37BL    68783.0   33399.0  14636.0   1919.0    19761.0    71165.0
# AL38LJ    64083.0   40080.0  11174.0   1981.0    20226.0    66959.0
# AL52BT    68783.0   33399.0  14636.0   1919.0    19761.0    71165.0
# AL54HX    68783.0   33399.0  14636.0   1919.0    19761.0    71165.0
# AL54QA    68783.0   33399.0  14636.0   1919.0    19761.0    71165.0
# AL69EF    52502.0   32048.0  10517.0   1690.0    36624.0    62514.0
# AL73UJ    52502.0   32048.0  10517.0   1690.0    36624.0    62514.0
# AL74HL    52502.0   32048.0  10517.0   1690.0    36624.0    62514.0
# AL74PL    52502.0   32048.0  10517.0   1690.0    36624.0    62514.0
# AL87QG    52502.0   32048.0  10517.0   1690.0    36624.0    62514.0
# AL97SN    52502.0   32048.0  10517.0   1690.0    36624.0    62514.0
# B100BS   198742.0  108993.0  23221.0   7241.0    76738.0   208050.0
# B100JL   198742.0  108993.0  23221.0   7241.0    76738.0   208050.0
# B100TU   198742.0  108993.0  23221.0   7241.0    76738.0   208050.0
# B100UG   198742.0  108993.0  23221.0   7241.0    76738.0   208050.0
# B109AB   198742.0  108993.0  23221.0   7241.0    76738.0   208050.0
# ...           ...       ...      ...      ...        ...        ...
# YO212PA   36001.0   61876.0   7521.0    924.0    13751.0    30946.0
# YO225DP   36001.0   61876.0   7521.0    924.0    13751.0    30946.0
# YO233UA   71453.0   53492.0  11920.0   1563.0    45686.0    73898.0
# YO243BZ   71453.0   53492.0  11920.0   1563.0    45686.0    73898.0
# YO243WX   71453.0   53492.0  11920.0   1563.0    45686.0    73898.0
# YO244DB   71453.0   53492.0  11920.0   1563.0    45686.0    73898.0
# YO244HD   71453.0   53492.0  11920.0   1563.0    45686.0    73898.0
# YO256EB   62622.0  101747.0  22176.0   2056.0    25521.0    57323.0
# YO256UH   62622.0  101747.0  22176.0   2056.0    25521.0    57323.0
# YO268BN   51081.0   55666.0  15745.0   1506.0    18772.0    41812.0
# YO317YD   71453.0   53492.0  11920.0   1563.0    45686.0    73898.0
# YO322LL   71453.0   53492.0  11920.0   1563.0    45686.0    73898.0
# YO325UA   71453.0   53492.0  11920.0   1563.0    45686.0    73898.0
# YO414DY   71453.0   53492.0  11920.0   1563.0    45686.0    73898.0
# YO422BS   62622.0  101747.0  22176.0   2056.0    25521.0    57323.0
# YO433FF   62622.0  101747.0  22176.0   2056.0    25521.0    57323.0
# YO519BD   51081.0   55666.0  15745.0   1506.0    18772.0    41812.0
# YO606PS   22256.0   35381.0   6808.0    574.0     7798.0    16839.0
# YO611LL   29473.0   44793.0  10063.0   1224.0    11318.0    27130.0
# YO611QW   29473.0   44793.0  10063.0   1224.0    11318.0    27130.0
# YO613JR   29473.0   44793.0  10063.0   1224.0    11318.0    27130.0
# YO624EF   22256.0   35381.0   6808.0    574.0     7798.0    16839.0
# YO625HD   22256.0   35381.0   6808.0    574.0     7798.0    16839.0
# YO626AR   22256.0   35381.0   6808.0    574.0     7798.0    16839.0
# YO71LG    29473.0   44793.0  10063.0   1224.0    11318.0    27130.0
# YO71LU    29473.0   44793.0  10063.0   1224.0    11318.0    27130.0
# YO73RP    29473.0   44793.0  10063.0   1224.0    11318.0    27130.0
# YO84BL    29782.0   32414.0   5993.0    841.0     9785.0    24763.0
# YO84QH    29782.0   32414.0   5993.0    841.0     9785.0    24763.0
# YO89AJ    29782.0   32414.0   5993.0    841.0     9785.0    24763.0
#
#          out_50_79  out_80p  moves_in_zscore  moves_out_zscore
# pcstrip
# AL100BS    44352.0  12340.0        -0.439573         -0.245584
# AL100NL    44352.0  12340.0        -0.439573         -0.245584
# AL108HP    44352.0  12340.0        -0.439573         -0.245584
# AL13FY     58917.0  13121.0        -0.412185         -0.165714
# AL13HD     58917.0  13121.0        -0.412185         -0.165714
# AL13JB     58917.0  13121.0        -0.412185         -0.165714
# AL14JE     58917.0  13121.0        -0.412185         -0.165714
# AL21ES     58917.0  13121.0        -0.412185         -0.165714
# AL21EU     58917.0  13121.0        -0.412185         -0.165714
# AL23JX     58917.0  13121.0        -0.412185         -0.165714
# AL35ER     58917.0  13121.0        -0.412185         -0.165714
# AL35HB     58917.0  13121.0        -0.412185         -0.165714
# AL35NF     58917.0  13121.0        -0.412185         -0.165714
# AL35NP     58917.0  13121.0        -0.412185         -0.165714
# AL37BL     58917.0  13121.0        -0.412185         -0.165714
# AL38LJ     57053.0  12704.0        -0.428034         -0.230365
# AL52BT     58917.0  13121.0        -0.412185         -0.165714
# AL54HX     58917.0  13121.0        -0.412185         -0.165714
# AL54QA     58917.0  13121.0        -0.412185         -0.165714
# AL69EF     44352.0  12340.0        -0.439573         -0.245584
# AL73UJ     44352.0  12340.0        -0.439573         -0.245584
# AL74HL     44352.0  12340.0        -0.439573         -0.245584
# AL74PL     44352.0  12340.0        -0.439573         -0.245584
# AL87QG     44352.0  12340.0        -0.439573         -0.245584
# AL97SN     44352.0  12340.0        -0.439573         -0.245584
# B100BS    148313.0  42135.0         3.096227          3.279381
# B100JL    148313.0  42135.0         3.096227          3.279381
# B100TU    148313.0  42135.0         3.096227          3.279381
# B100UG    148313.0  42135.0         3.096227          3.279381
# B109AB    148313.0  42135.0         3.096227          3.279381
# ...            ...      ...              ...               ...
# YO212PA    39556.0  10532.0        -0.641138         -0.916078
# YO225DP    39556.0  10532.0        -0.641138         -0.916078
# YO233UA    49971.0  11280.0         0.227410          0.024280
# YO243BZ    49971.0  11280.0         0.227410          0.024280
# YO243WX    49971.0  11280.0         0.227410          0.024280
# YO244DB    49971.0  11280.0         0.227410          0.024280
# YO244HD    49971.0  11280.0         0.227410          0.024280
# YO256EB    79250.0  19815.0         0.569226          0.041278
# YO256UH    79250.0  19815.0         0.569226          0.041278
# YO268BN    51860.0  12406.0        -0.365722         -0.583635
# YO317YD    49971.0  11280.0         0.227410          0.024280
# YO322LL    49971.0  11280.0         0.227410          0.024280
# YO325UA    49971.0  11280.0         0.227410          0.024280
# YO414DY    49971.0  11280.0         0.227410          0.024280
# YO422BS    79250.0  19815.0         0.569226          0.041278
# YO433FF    79250.0  19815.0         0.569226          0.041278
# YO519BD    51860.0  12406.0        -0.365722         -0.583635
# YO606PS    24487.0   5721.0        -1.198545         -1.353123
# YO611LL    33872.0  11988.0        -0.919829         -1.026472
# YO611QW    33872.0  11988.0        -0.919829         -1.026472
# YO613JR    33872.0  11988.0        -0.919829         -1.026472
# YO624EF    24487.0   5721.0        -1.198545         -1.353123
# YO625HD    24487.0   5721.0        -1.198545         -1.353123
# YO626AR    24487.0   5721.0        -1.198545         -1.353123
# YO71LG     33872.0  11988.0        -0.919829         -1.026472
# YO71LU     33872.0  11988.0        -0.919829         -1.026472
# YO73RP     33872.0  11988.0        -0.919829         -1.026472
# YO84BL     32583.0   4567.0        -1.122847         -1.167414
# YO84QH     32583.0   4567.0        -1.122847         -1.167414
# YO89AJ     32583.0   4567.0        -1.122847         -1.167414
#
# [6594 rows x 63 columns]

# %%
features.dropna().to_csv("features2.csv")

# %% [markdown]
# # Features array at the LAD level

# %%
# test = JGI2018[1].merge(features, left_on='pcstrip', right_index=True)

# %%
# features_lad = test.groupby('laua').mean()[['target',
#        'A1', 'B1', 'C1', 'C2', 'D1', 'D2', 'E1', 'E2', 'F1', 'F2', 'region_1',
#        'region_2', 'region_3', 'region_4', 'region_5', 'region_6', 'region_7',
#        'region_8', 'region_9', 'index_multiple_deprivation', '0-9', '10-24',
#        '25-49', '50-79', '80+', 'nearby_schools', 'Academy', 'College',
#        'Independent School', 'Maintained School', 'Special School', 'in_0-9',
#        'in_10-24', 'in_25-49', 'in_50-79', 'in_80+', 'out_0-9', 'out_10-24',
#        'out_25-49', 'out_50-79', 'out_80+', 'moves_in_zscore',
#        'moves_out_zscore', 'schools_many', 'prop_score', 'norm_0-9',
#        'norm_10-24', 'norm_25-49', 'norm_50-79', 'norm_80+', 'ru_rank',
#        'tot_patients', 'nearby_schools_zscore', 'norm_in_0-9', 'norm_in_10-24',
#        'norm_in_25-49', 'norm_in_50-79', 'norm_in_80+', 'norm_out_0-9',
#        'norm_out_10-24', 'norm_out_25-49', 'norm_out_50-79', 'norm_out_80+']]
